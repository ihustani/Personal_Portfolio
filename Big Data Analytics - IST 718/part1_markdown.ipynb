# %% [markdown]
# # IST 718: Big Data Analytics
#
# - Professor: Daniel Acuna <deacuna@syr.edu>
#
# ## General instructions:
#
# - You are welcome to discuss the problems with your classmates but __you are not allowed to copy any part of your answers either from your classmates or from the internet__
# - You can put the homework files anywhere you want in your https://jupyterhub.ischool.syr.edu/ workspace but _do not change_ the file names. The TAs and the professor use these names to grade your homework.
# - Remove or comment out code that contains `raise NotImplementedError`. This is mainly to make the `assert` statement fail if nothing is submitted.
# - The tests shown in some cells (i.e., `assert` and `np.testing.` statements) are used to grade your answers. **However, the professor and TAs will use __additional__ test for your answer. Think about cases where your code should run even if it passess all the tests you see.**
# - Before downloading and submitting your work through Blackboard, remember to save and press `Validate` (or go to
# `Kernel`$\rightarrow$`Restart and Run All`).
# - Good luck!

# %% [markdown]
# # Part 1: Markdown

# %% [markdown]
# ## Question 1.1 (5 pts)
#
# In the following Markdown cell, write any text and add formatting so that there is one phrase or word that is italized, another phrase or word that is bold faced, and a phrase or word that is both bold and italic.

# %% [markdown]
# *this is italic* **this is bold** ***this is both***

# %% [markdown]
# ## Question 1.2 (5 pts)
#
# Add a link to Syracuse University that shows the text "Syracuse University" and goes to the URL http://www.syracuse.edu This means that the rendered Markdown __should not__ display the URL.

# %% [markdown]
# __[Syracuse University](http://www.syracuse.edu)__

# %% [markdown]
# ## Question 1.3 (5 pts)
#
# Create all six levels of headings with the text "H1", "H2", ..., "H6"

# %% [markdown]
# # H1
# ## H2
# ### H3
# #### H4
# ##### H5
# ###### H6

# %% [markdown]
# ## Question 1.4 (5 pts)
#
# Using Markdown, display the image whose URL is http://jupyter.org/assets/hublogo.svg

# %% [markdown]
# ![](https://jupyter.org/assets/hublogo.svg)

# %% [markdown]
# ## Question 1.5 (5 pts)
#
# Create a sequence list where the first level contains "Introduction", "Methods", "Results", and "Conclusion". Within "Introduction", create a second level that contains "State of the art" and "This article". Within "Methods", create a second level that contains a list with "Data" and "Algorithms". Within "Conclusion", create a second level that contains a list with "This article" and "Future work"

# %% [markdown]
# 1. Introduction
#     * State of the art
#     * This article
# 2. Methods
#     * Data
#     * Algorithms
# 3. Results
# 4. Conclusion
#     * This article
#     * Future work

# %% [markdown]
# ## Question 2.6 (5 pts)

# %% [markdown]
# In markdown, create a cell that contains the following information and formating. The graph's URL is https://cdn-images-1.medium.com/max/1600/1*EqTaoCB1NmJnsRYEezSACA.png
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Loss functions
# In class, we proposed a **model** $y=f_\theta(x)$ and a **loss function** $L(\theta)$. We can find the *minimum* of this function by taking the derivative. If the function is quadratic, such loss function will look like this:
# ![](https://cdn-images-1.medium.com/max/1600/1*EqTaoCB1NmJnsRYEezSACA.png)
